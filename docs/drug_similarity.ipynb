# %%
import pandas as pd
import numpy as np
from urllib.parse import quote
import requests
import time
import bot

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs

import pickle

# %% [markdown]
# # Get SMILES notation

# %%
meds_raw = pd.read_csv('medecines.csv')
meds = meds_raw.iloc[8:,1:]
meds.columns = meds_raw.iloc[7,1:]
human_meds = meds.loc[:,'Category'] == 'Human'
meds = meds[human_meds]
meds = meds.reset_index(drop=True)
meds.head(3)
# Out:
# 7 Category    Medicine name                                  Therapeutic area
# 0    Human          Lenvima                                 Thyroid Neoplasms  \
# 1    Human  Febuxostat Krka                              Hyperuricemia;  Gout
# 2    Human          Tasigna  Leukemia, Myelogenous, Chronic, BCR-ABL Positive
#
# 7 International non-proprietary name (INN) / common name     Active substance
# 0                                         lenvatinib      lenvatinib mesilate  \
# 1                                         febuxostat               febuxostat
# 2                                          nilotinib                nilotinib
#
# 7   Product number Patient safety Authorisation status ATC code
# 0  EMEA/H/C/003727             no           Authorised    L01XE  \
# 1  EMEA/H/C/004773             no           Authorised  M04AA03
# 2  EMEA/H/C/000798             no           Authorised  L01EA03
#
# 7 Additional monitoring  ... Vet pharmacotherapeutic group
# 0                   yes  ...                           NaN  \
# 1                    no  ...                           NaN
# 2                    no  ...                           NaN
#
# 7      Date of opinion        Decision date Revision number
# 0  2015-03-26 01:00:00  2023-03-09 01:00:00              18  \
# 1  2019-01-31 01:00:00  2023-05-11 00:00:00               4
# 2                  NaN  2022-05-19 00:00:00              42
#
# 7                             Condition / indication Species ATCvet code
# 0  Lenvima is indicated as monotherapy for the tr...     NaN         NaN  \
# 1  Febuxostat Krka is indicated for the treatment...     NaN         NaN
# 2  Tasigna is indicated for the treatment of:adul...     NaN         NaN
#
# 7      First published        Revision date
# 0  2018-06-21 12:16:00  2023-05-11 15:24:00  \
# 1  2019-03-29 17:03:00  2023-05-11 15:01:00
# 2  2017-11-15 01:09:00  2023-05-11 14:40:00
#
# 7                                                URL
# 0  https://www.ema.europa.eu/en/medicines/human/E...
# 1  https://www.ema.europa.eu/en/medicines/human/E...
# 2  https://www.ema.europa.eu/en/medicines/human/E...
#
# [3 rows x 30 columns]

# %%
def pubchem_lookup(active_substance):
    '''
    searches for Canonical Smiles in the PubChem database
    '''
    url_substance = quote(active_substance)
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{url_substance}/property/CanonicalSMILES/TXT"
    response = requests.get(url)
    if response.status_code != 200:
        return None
    else:
        smiles = response.content.decode('utf-8')[:-1]
        return smiles

# %%
def fill_smiles_column():
    '''
    Wrapper for the pubchem_lookup function to fill entire column
    with Canonical smile notation.
    makes max 5 requests per second to comply with the API 
    '''

    for idx, active_substance in enumerate(meds.loc[:,'Active substance']):
        try:
            # only lookup first active substance
            substance1 = active_substance.split(',')[0]
            smiles = pubchem_lookup(substance1)
            meds.loc[idx,'smiles'] = smiles
        except:
            meds.loc[idx,'smiles'] = None
        # To comply with pubchem usage policy
        if idx % 5 == 0:
            time.sleep(1)

# %%
bot.botrun(fill_smiles_column())

# %%
def advanced_smiles_lookup(active_substance):
    '''
    If first search doesnt yield results then this option can be used
    takes much more time than first option and opens browsers in the
    background.

    Uses Google Chrome
    '''
    options = Options()
    options.headless = True
    driver = webdriver.Chrome(options=options)
    driver.get('https://pubchem.ncbi.nlm.nih.gov/')


    search = driver.find_element(By.XPATH, '//input[@type="text" and @placeholder=""]')
    search.send_keys(f'{active_substance}')


    search_button = driver.find_element(By.CLASS_NAME, 'main-search-submit')
    search_button.click()
    time.sleep(2)
    first_element = driver.find_element(By.CSS_SELECTOR,'[data-action="result-link"]')
    first_element.click()
    time.sleep(2)
    smiles_div = driver.find_element(By.ID, 'Canonical-SMILES')
    div_text = smiles_div.text
    smiles = div_text.split('\n')[1]
    driver.close()
    return smiles

# %%
holdouts = meds[meds.loc[:,'smiles'].isna()]
indicies = list(holdouts.index)
indicies
substances = list(holdouts.loc[:,'Active substance'])
substances
for idx, active_substance in zip(indicies,substances):
    try:
            substance1 = active_substance.split(',')[0]
            smiles = advanced_smiles_lookup(substance1)
            meds.loc[idx,'smiles'] = smiles
    except:
          pass
# Out:
# C:\Users\Ben\AppData\Local\Temp\ipykernel_33040\3360539619.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('--headless') or add_argument('--headless=new')
#   options.headless = True

# %%
sum(meds.loc[:,'smiles'].isna())/len(meds)
# Out:
# 0.25

# %%
meds.to_pickle('meds_w_smiles')

# %% [markdown]
# # Calculate similarity scores

# %%
meds = pd.read_pickle('meds_w_smiles')

# %%
def tanimoto_calc(smi1, smi2):
    mol1 = Chem.MolFromSmiles(smi1)
    mol2 = Chem.MolFromSmiles(smi2)
    fp1 = AllChem.GetMorganFingerprintAsBitVect(mol1, 3, nBits=2048)
    fp2 = AllChem.GetMorganFingerprintAsBitVect(mol2, 3, nBits=2048)
    s = round(DataStructs.TanimotoSimilarity(fp1,fp2),3)
    return s

# %%
tanimoto_calc(meds.loc[0,'smiles'], meds.loc[3,'smiles'])
# Out:
# 0.07

# %%
# all unique active substances
unique_active = meds.drop_duplicates(subset=['smiles'])

smiles = unique_active.loc[:,'smiles'].dropna()
smiles = list(smiles)
nr_smiles = len(smiles)
similarity = np.zeros([nr_smiles, nr_smiles])

# %%
for i in range(nr_smiles):
    for j in range(nr_smiles-i):
        try:
            sim_score = tanimoto_calc(smiles[i], smiles[j])
            similarity[i,j] = similarity[j,i] = sim_score
        except:
            similarity[i,j] = similarity[j,i] = None
# Out:
# [19:30:28] WARNING: not removing hydrogen atom without neighbors
# [19:30:28] WARNING: not removing hydrogen atom without neighbors
# [19:30:28] WARNING: not removing hydrogen atom without neighbors
# [19:30:30] WARNING: not removing hydrogen atom without neighbors
# [19:30:30] WARNING: not removing hydrogen atom without neighbors
# [19:30:30] WARNING: not removing hydrogen atom without neighbors
# [19:30:32] WARNING: not removing hydrogen atom without neighbors
# [19:30:32] WARNING: not removing hydrogen atom without neighbors
# [19:30:32] WARNING: not removing hydrogen atom without neighbors
# [19:30:35] WARNING: not removing hydrogen atom without neighbors
# [19:30:35] WARNING: not removing hydrogen atom without neighbors
# [19:30:35] WARNING: not removing hydrogen atom without neighbors
# [19:30:38] WARNING: not removing hydrogen atom without neighbors
# [19:30:38] WARNING: not removing hydrogen atom without neighbors
# [19:30:38] WARNING: not removing hydrogen atom without neighbors
# [19:30:40] WARNING: not removing hydrogen atom without neighbors
# [19:30:40] WARNING: not removing hydrogen atom without neighbors
# [19:30:40] WARNING: not removing hydrogen atom without neighbors
# [19:30:42] WARNING: not removing hydrogen atom without neighbors
# [19:30:42] WARNING: not removing hydrogen atom without neighbors
# [19:30:42] WARNING: not removing hydrogen atom without neighbors
# [19:30:44] WARNING: not removing hydrogen atom without neighbors
# [19:30:44] WARNING: not removing hydrogen atom without neighbors
# [19:30:44] WARNING: not removing hydrogen atom without neighbors
# [19:30:48] WARNING: not removing hydrogen atom without neighbors
# [19:30:48] WARNING: not removing hydrogen atom without neighbors
# [19:30:48] WARNING: not removing hydrogen atom without neighbors
# [19:30:51] WARNING: not removing hydrogen atom without neighbors
# [19:30:51] WARNING: not removing hydrogen atom without neighbors
# [19:30:51] WARNING: not removing hydrogen atom without neighbors
# [19:30:54] WARNING: not removing hydrogen atom without neighbors
# [19:30:54] WARNING: not removing hydrogen atom without neighbors
# [19:30:54] WARNING: not removing hydrogen atom without neighbors
# [19:30:57] WARNING: not removing hydrogen atom without neighbors
# [19:30:57] WARNING: not removing hydrogen atom without neighbors
# [19:30:57] WARNING: not removing hydrogen atom without neighbors
# [19:30:59] WARNING: not removing hydrogen atom without neighbors
# [19:30:59] WARNING: not removing hydrogen atom without neighbors
# [19:30:59] WARNING: not removing hydrogen atom without neighbors
# [19:31:02] WARNING: not removing hydrogen atom without neighbors
# [19:31:02] WARNING: not removing hydrogen atom without neighbors
# [19:31:02] WARNING: not removing hydrogen atom without neighbors
# [19:31:04] WARNING: not removing hydrogen atom without neighbors
# [19:31:04] WARNING: not removing hydrogen atom without neighbors
# [19:31:04] WARNING: not removing hydrogen atom without neighbors
# [19:31:07] WARNING: not removing hydrogen atom without neighbors
# [19:31:07] WARNING: not removing hydrogen atom without neighbors
# [19:31:07] WARNING: not removing hydrogen atom without neighbors
# [19:31:09] WARNING: not removing hydrogen atom without neighbors
# [19:31:09] WARNING: not removing hydrogen atom without neighbors
# [19:31:09] WARNING: not removing hydrogen atom without neighbors
# [19:31:12] WARNING: not removing hydrogen atom without neighbors
# [19:31:12] WARNING: not removing hydrogen atom without neighbors
# [19:31:12] WARNING: not removing hydrogen atom without neighbors
# [19:31:15] WARNING: not removing hydrogen atom without neighbors
# [19:31:15] WARNING: not removing hydrogen atom without neighbors
# [19:31:15] WARNING: not removing hydrogen atom without neighbors
# [19:31:17] WARNING: not removing hydrogen atom without neighbors
# [19:31:17] WARNING: not removing hydrogen atom without neighbors
# [19:31:17] WARNING: not removing hydrogen atom without neighbors
# [19:31:20] WARNING: not removing hydrogen atom without neighbors
# [19:31:20] WARNING: not removing hydrogen atom without neighbors
# [19:31:20] WARNING: not removing hydrogen atom without neighbors
# [19:31:22] WARNING: not removing hydrogen atom without neighbors
# [19:31:22] WARNING: not removing hydrogen atom without neighbors
# [19:31:22] WARNING: not removing hydrogen atom without neighbors
# [19:31:25] WARNING: not removing hydrogen atom without neighbors
# [19:31:25] WARNING: not removing hydrogen atom without neighbors
# [19:31:25] WARNING: not removing hydrogen atom without neighbors
# [19:31:27] WARNING: not removing hydrogen atom without neighbors
# [19:31:27] WARNING: not removing hydrogen atom without neighbors
# [19:31:27] WARNING: not removing hydrogen atom without neighbors
# [19:31:38] WARNING: not removing hydrogen atom without neighbors
# [19:31:38] WARNING: not removing hydrogen atom without neighbors
# [19:31:38] WARNING: not removing hydrogen atom without neighbors
# [19:32:04] WARNING: not removing hydrogen atom without neighbors
# [19:32:04] WARNING: not removing hydrogen atom without neighbors
# [19:32:04] WARNING: not removing hydrogen atom without neighbors
# [19:32:07] WARNING: not removing hydrogen atom without neighbors
# [19:32:07] WARNING: not removing hydrogen atom without neighbors
# [19:32:07] WARNING: not removing hydrogen atom without neighbors
# [19:32:09] WARNING: not removing hydrogen atom without neighbors
# [19:32:09] WARNING: not removing hydrogen atom without neighbors
# [19:32:09] WARNING: not removing hydrogen atom without neighbors
# [19:32:12] WARNING: not removing hydrogen atom without neighbors
# [19:32:12] WARNING: not removing hydrogen atom without neighbors
# [19:32:12] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors
# [19:49:17] WARNING: not removing hydrogen atom without neighbors

# %%
dist_matrix = 1 - similarity

# %%
np.save('distance_mat', dist_matrix)

# %%
with open("smiles", "wb") as file:   #Pickling
    pickle.dump(smiles, file)

# %% [markdown]
# # Other stuff

# %%
from collections import Counter

# %%
from collections import Counter
sorted(Counter(meds.loc[:,'Human pharmacotherapeutic group']).items(), key=lambda x:x[1], reverse=True)
# Out:
# [('Antineoplastic agents', 252),
#  ('Immunosuppressants', 108),
#  ('Drugs used in diabetes', 97),
#  ('Antivirals for systemic use', 96),
#  ('Vaccines, ', 68),
#  ('Antithrombotic agents', 66),
#  ('Drugs for obstructive airway diseases, ', 44),
#  ('Agents acting on the renin-angiotensin system', 43),
#  ('Other alimentary tract and metabolism products, ', 42),
#  ('Psycholeptics', 40),
#  ('Immunostimulants, ', 39),
#  ('Antihemorrhagics', 32),
#  ('Antiepileptics, ', 30),
#  ('Ophthalmologicals', 30),
#  ('Antibacterials for systemic use, ', 29),
#  (nan, 29),
#  ('Drugs for treatment of bone diseases', 27),
#  ('Sex hormones and modulators of the genital system, ', 26),
#  ('Urologicals', 24),
#  ('All other therapeutic products', 23),
#  ('Other nervous system drugs', 23),
#  ('Anti-Parkinson drugs', 23),
#  ('Psychoanaleptics, ', 22),
#  ('Diagnostic radiopharmaceuticals', 18),
#  ('Calcium homeostasis', 17),
#  ('Lipid modifying agents', 15),
#  ('Pituitary and hypothalamic hormones and analogues', 14),
#  ('Cardiac therapy', 13),
#  ('Immune sera and immunoglobulins, ', 12),
#  ('Antimycotics for systemic use', 12),
#  ('Endocrine therapy', 11),
#  ('Analgesics', 11),
#  ('Antianemic preparations', 10),
#  ('Other hematological agents', 9),
#  ('Antihistamines for systemic use, ', 9),
#  ('Other drugs for disorders of the musculo-skeletal system', 8),
#  ('Other dermatological preparations', 8),
#  ('Drugs used in diabetes, Combinations of oral blood glucose lowering drugs',
#   8),
#  ('Antiobesity preparations, excl. diet products', 7),
#  ('Selective immunosuppressants', 7),
#  ('Antineoplastic agents, Protein kinase inhibitors', 7),
#  ('Therapeutic radiopharmaceuticals', 7),
#  ('Contrast media', 7),
#  ('Antigout preparations', 6),
#  ('Antiemetics and antinauseants, ', 6),
#  ('Proton pump inhibitors', 6),
#  ('Anesthetics', 6),
#  ('Other antianemic preparations', 6),
#  ('Protein kinase inhibitors', 5),
#  ('Other respiratory system products', 5),
#  ('Other anti-dementia drugs', 5),
#  ('Antihypertensives, ', 5),
#  ('Corticosteroids for systemic use', 5),
#  ('Antiinflammatory and antirheumatic products', 5),
#  ('Bile and liver therapy', 4),
#  ('Antimycobacterials', 4),
#  ('Preparations for treatment of wounds and ulcers', 4),
#  ('Antibiotics and chemotherapeutics for dermatological use', 4),
#  ('Diagnostic agents', 4),
#  ('Antidiarrheals, intestinal antiinflammatory / antiinfective agents', 4),
#  ('Influenza vaccines', 4),
#  ('Immunostimulants, , Colony stimulating factors', 3),
#  ('Other alimentary tract and metabolism products', 3),
#  ('Antivirals for systemic use, Antivirals for treatment of HIV infections, combinations',
#   3),
#  ('Nervous system', 3),
#  ('Other antineoplastic agents', 3),
#  ('Cardiovascular system', 3),
#  ('Antiepileptics, , Other antiepileptics', 2),
#  ('Not yet assigned', 2),
#  ('Psychoanaleptics, , Other anti-dementia drugs', 2),
#  ('Antiprotozoals', 2),
#  ('Monoclonal antibodies', 2),
#  ('Drugs for treatment of hyperkalemia and hyperphosphatemia', 2),
#  ('Antiemetics and antinauseants, , Serotonin (5HT3) antagonists', 2),
#  ('Other antineoplastic agents, Protein kinase inhibitors', 2),
#  ('Antineoplastic and immunomodulating agents', 2),
#  ('Nucleoside and nucleotide reverse transcriptase inhibitors', 2),
#  ('Other antidepressants', 2),
#  ('Angiotensin II antagonists, plain', 2),
#  ('Antivirals for treatment of HIV infections, combinations, Antivirals for systemic use',
#   2),
#  ('Adrenergics and other drugs for obstructive airway diseases', 2),
#  ('Pancreatic hormones, Glycogenolytic hormones', 2),
#  ('Nasal preparations', 2),
#  ('Immunosuppressants, Selective immunosuppressants', 2),
#  ('Diuretics, ', 2),
#  ('Drugs for functional gastrointestinal disorders', 2),
#  ('Drugs used in erectile dysfunction', 2),
#  ('Other gynecologicals', 2),
#  ('Bisphosphonates', 2),
#  ('Drugs used in diabetes, Insulins and analogues for injection, fast-acting ',
#   2),
#  ('All other therapeutic products, Iron chelating agents', 1),
#  ('doxorubicin', 1),
#  ('Alimentary tract and metabolism', 1),
#  ('Muscle relaxants', 1),
#  ('Antineoplastic agents, protein kinase inhibitors, ', 1),
#  ('Papillomavirus vaccines', 1),
#  ('Sex hormones and modulators of the genital system, , Emergency contraceptives',
#   1),
#  ('Vaccines, , Viral vaccines', 1),
#  ('Other alimentary tract and metabolism products, Enzymes', 1),
#  ('Anterior pituitary lobe hormones and analogues, Pituitary and hypothalamic hormones and analogues',
#   1),
#  ('Immunosuppressant', 1),
#  ('Other viral vaccines, ', 1),
#  ('Antibacterials for systemic use, , Other antibacterials', 1),
#  ('Other anti-dementia drugs, Psychoanaleptics, ', 1),
#  ('Iron chelating agents', 1),
#  ('Other antineoplastic agents, Monoclonal antibodies', 1),
#  ('Agents for dermatitis, excluding corticosteroids', 1),
#  ('Vaccines, , Bacterial and viral vaccines, combined', 1),
#  ('monoclonal antibodies and antibody drug conjugates, Antineoplastic agents',
#   1),
#  ('Blood coagulation factors', 1),
#  ('Antimigraine preparations, calcitonin gene-related peptide (CGRP) antagonists',
#   1),
#  ('influenza, inactivated, split virus or surface antigen', 1),
#  ('Endocrine therapy, Other hormone antagonists and related agents', 1),
#  ('Drugs used in diabetes, Blood glucose lowering drugs, excl. insulins', 1),
#  ('Drugs for constipation, Peripheral opioid receptor antagonists', 1),
#  ('Other cardiac preparations', 1),
#  ('Immunosuppressants, Interleukin inhibitors, ', 1),
#  ('Antivirals for treatment of HIV infections, combinations', 1),
#  ('Detoxifying agents for antineoplastic treatment', 1),
#  ('Antiadrenergic agents, centrally acting, Antihypertensives, ', 1),
#  ('Other therapeutic radiopharmaceuticals', 1),
#  ('Other antihypertensives', 1),
#  ('Beta blocking agents', 1),
#  ('Influenza vaccines, Influenza, live attenuated', 1),
#  ('Drugs used in diabetes, Glucagon-like peptide-1 (GLP-1) analogues', 1),
#  ('Bacterial vaccines', 1),
#  ('Vitamin K and other hemostatics, Antihemorrhagics, coagulation factor X',
#   1),
#  ('Meningococcal vaccines', 1),
#  ('Bile acids and derivatives', 1),
#  ('Drugs used in diabetes, Dipeptidyl peptidase 4 (DPP-4) inhibitors', 1),
#  ('Angiotensin II antagonists, combinations, Agents acting on the renin-angiotensin system, Angiotensin II antagonists and calcium channel blockers',
#   1),
#  ('Antineoplastic Agents and Antibody Drug Conjugates', 1),
#  ('Other drugs for constipation', 1),
#  ('Other drugs for bile therapy', 1),
#  ('imatinib', 1),
#  ('Peripheral opioid receptor antagonists, Drugs for constipation', 1),
#  ('Drugs used in diabetes, Sodium-glucose co-transporter 2 (SGLT2) inhibitors',
#   1),
#  ('PITUITARY AND HYPOTHALAMIC HORMONES AND ANALOGUES', 1),
#  ('Immunosuppressants, Tumor necrosis factor alpha (TNF-α) inhibitors', 1),
#  ('Bacterial vaccines, Meningococcal vaccines', 1),
#  ('Antivirals for systemic use, Protease inhibitors', 1),
#  ('Carbapenems, Antibacterials for systemic use, ', 1),
#  ('pneumococcus, purified polysaccharides antigen conjugated', 1),
#  ('Non-nucleoside reverse transcriptase inhibitors, Antivirals for systemic use',
#   1),
#  ('Anti-Parkinson drugs, Other dopaminergic agents', 1),
#  ('Antivirals for systemic use, Antivirals for treatment of HCV infections',
#   1),
#  ('ertapenem', 1),
#  ('Direct acting antivirals, Antivirals for systemic use, Antivirals for treatment of HCV infections',
#   1),
#  ('Amides, Anesthetics, local', 1),
#  ('Analgesics, galcanezumab', 1),
#  ('Other lipid modifying agents', 1),
#  ('Emollients and protectives', 1),
#  ('Other systemic hemostatics, Antihemorrhagics', 1),
#  ('Other sex hormones and modulators of the genital system', 1),
#  ('Peripheral opioid receptor antagonists', 1),
#  ('Other psychostimulants and nootropics, Psychoanaleptics, ', 1),
#  ('Monoclonal antibodies, Antineoplastic agents', 1),
#  ('c1-inhibitor, plasma derived, Drugs used in hereditary angioedema', 1),
#  ('Allergens', 1),
#  ('Interleukin inhibitors, ', 1),
#  ('Other systemic hemostatics', 1),
#  ('Antineoplastic agents, Taxanes', 1),
#  ('Angiotensin II antagonists, other combinations, Agents acting on the renin-angiotensin system',
#   1),
#  ('Endocrine therapy, Anti-estrogens', 1),
#  ('Agents acting on the renin-angiotensin system, Angiotensin II antagonists and diuretics',
#   1),
#  ('Drugs for constipation', 1),
#  ('Coxibs, Antiinflammatory and antirheumatic products', 1),
#  ('Folic acid analogues, Antineoplastic agents', 1),
#  ('Ophthalmologicals, Other ophthalmologicals', 1),
#  ('Prostaglandin analogues, Ophthalmologicals', 1),
#  ('Topotecan', 1),
#  ('formoterol and glycopyrronium bromide', 1),
#  ('Dipeptidyl peptidase 4 (DPP-4) inhibitors, Drugs used in diabetes', 1),
#  ('Drugs for treatment of bone diseases, Bisphosphonates', 1),
#  ('Protein kinase inhibitors, Antineoplastic agents', 1),
#  ('various', 1),
#  ('Viral vaccines', 1),
#  ('Cough and cold preparations', 1),
#  ('Other antiepileptics', 1),
#  ('Antihypertensives for pulmonary arterial hypertension', 1),
#  ('Other muscle relaxants, peripherally acting agents', 1),
#  ('Calcitonin gene-related peptide (CGRP) antagonists', 1),
#  ('Drugs used in alcohol dependence', 1),
#  ('Blood coagulation factors, von Willebrand factor and coagulation factor VIII in combination, Antihemorrhagics',
#   1),
#  ('migalastat', 1),
#  ('Mineral supplements', 1),
#  ('Antimycotics for systemic use, Triazole derivatives', 1),
#  ('Nasal preparations, Corticosteroids', 1),
#  ('telmisartan and diuretics', 1),
#  ('Urologicals, Drugs for urinary frequency and incontinence', 1),
#  ('conjugated estrogens and bazedoxifene', 1),
#  ('Enzymes', 1),
#  ('Various alimentary tract and metabolism products', 1),
#  ('Antineoplastic agents, Monoclonal antibodies', 1),
#  ('Antivirals for systemic use, Neuraminidase inhibitors', 1),
#  ('Ophthalmologicals, Antiglaucoma preparations and miotics', 1),
#  ('macimorelin', 1),
#  ('Other systemic drugs for obstructive airway diseases, ', 1),
#  ('Urologicals, Alpha-adrenoreceptor antagonists', 1),
#  ('Vitamin K and other hemostatics, Blood coagulation factors', 1),
#  ('Antineoplastic agents, Other antineoplastic agents', 1),
#  ('Anti-parathyroid agents, Calcium homeostasis', 1),
#  ('Adrenergics in combinations with anticholinergics incl. triple combinations with corticosteroids',
#   1),
#  ('Adrenergics in combinations with anticholinergics incl. triple combinations with corticosteroids, Drugs for obstructive airway diseases, ',
#   1),
#  ('Folic acid analogues, ANTIMETABOLITES', 1),
#  ('Other diagnostic agents', 1),
#  ('coagulation factor VIII', 1),
#  ('Alkyl sulfonates', 1),
#  ('Drugs used in hereditary angioedema, Other hematological agents', 1),
#  ('Digestives, incl. enzymes', 1),
#  ('Tumour detection, Diagnostic radiopharmaceuticals', 1),
#  ('Antibiotics and chemotherapeutics for dermatological use, Other chemotherapeutics',
#   1),
#  ('Vitamins', 1),
#  ('Antibacterials for systemic use, , Aminoglycoside antibacterials', 1),
#  ('Local hemostatics', 1),
#  ('Pituitary and hypothalamic hormones and analogues, Somatropin and somatropin agonists',
#   1),
#  ('combinations', 1),
#  ('Colony stimulating factors', 1),
#  ('capecitabine', 1),
#  ('Drugs for treatment of bone diseases, Bone morphogenetic proteins', 1),
#  ('Antineoplastic and immunomodulating agents, Monoclonal antibodies', 1),
#  ('Other immunostimulants', 1),
#  ('Psychoanaleptics, , Anticholinesterases', 1),
#  ('Other vasodilators used in cardiac diseases', 1),
#  ('Angiotensin II antagonists, plain, Angiotensin II antagonists, combinations',
#   1),
#  ('Anticholinesterases', 1),
#  ('Specific immunoglobulins', 1)]

# %%
no_smiles = meds[meds.loc[:,'smiles'].isna()]
no_smiles.head(3)
